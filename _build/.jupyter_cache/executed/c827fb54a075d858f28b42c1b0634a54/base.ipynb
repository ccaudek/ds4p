# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats 
import pymc as pm
import pymc.sampling_jax
import arviz as az
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=Warning)

# %%
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 42
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-darkgrid")
sns.set_theme(palette="colorblind")

# %%
alpha = 4
beta = 6
y = 14
n = 100
alpha_prime = alpha + y
beta_prime = beta + n - y
m = 20
x = np.arange(0, 20)

plt.plot(
    x,
    stats.betabinom.pmf(x, m, alpha_prime, beta_prime),
    "C0o",
    ms=5,
    label="betabinom pmf",
)
_ = plt.vlines(
    x,
    0,
    stats.betabinom.pmf(x, m, alpha_prime, beta_prime),
    colors="C1",
    lw=2,
    alpha=0.5,
)

# Set x-ticks to be every 5 units
plt.xticks(np.arange(0, 21, 5))

plt.xlabel("x")
plt.ylabel("Probability")
_ = plt.title("Beta-Binomial PMF")

# %%
1 - stats.betabinom.cdf(4, m, alpha_prime, beta_prime).sum()
# Out:
# 0.23298739435887628

# %%
x = np.arange(0, 21)
px = stats.betabinom.pmf(np.arange(0, 21), m, alpha_prime, beta_prime)

ev = sum(x * px)
print(ev)
# Out:
# 3.272727272727284

# %%
nrep = 100000
theta = stats.beta.rvs(alpha_prime, beta_prime, size=nrep)
print(*theta[0:10])
# Out:
# 0.16304775652829975 0.19512150111163504 0.1671815775397448 0.20677888048667623 0.16243338179893385 0.1421523114729382 0.2026061997790337 0.14222772477819917 0.12822537713223903 0.2569777391072043

# %%
y_tilde = [stats.binom.rvs(n=20, p=th, size=1) for th in theta]
y_tilde = np.concatenate(y_tilde)
print(*y_tilde[0:50])
# Out:
# 3 2 3 5 1 4 2 4 3 5 4 1 4 5 2 1 3 1 0 6 4 3 0 4 5 3 5 6 3 6 6 1 6 4 0 5 2 1 2 2 3 6 4 3 2 4 1 0 4 1

# %%
hist, bins, _ = plt.hist(y_tilde, bins=range(0, 22), density=True, alpha=0.5)
bin_centers = (bins[:-1] + bins[1:]) / 2
px = stats.betabinom.pmf(np.arange(0, 21), m, alpha_prime, beta_prime)
plt.plot(bin_centers, px, "o", color="C0", label="Beta-Binomial");

# %%
az.plot_posterior(y_tilde, hdi_prob=0.8, kind="kde", bw=0.5);

# %%
ntrials = 100
y = 14

alpha_prior = 4
beta_prior = 6

with pm.Model() as model:
    theta = pm.Beta("theta", alpha=alpha_prior, beta=beta_prior)
    obs = pm.Binomial("obs", p=theta, n=ntrials, observed=y)

# %%
with model:
    idata = pm.sampling_jax.sample_numpyro_nuts()
# Out:
# Compiling...
# Compilation time = 0:00:01.564156
# Sampling...
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Sampling time = 0:00:02.637095
# Transforming variables...
# Transformation time = 0:00:00.095414

# %%
az.summary(idata)
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# theta  0.164  0.035   0.099    0.229      0.001    0.001    1390.0    1879.0
#
#        r_hat
# theta    1.0

# %%
with model:
    post_pred = pm.sample_posterior_predictive(idata)
# Out:
# Sampling: [obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:00&lt;00:00]
#     </div>

# %%
post_pred.posterior_predictive.obs
# Out:
# <xarray.DataArray 'obs' (chain: 4, draw: 1000)>
# array([[14, 13, 14, ..., 17, 21, 22],
#        [18, 20, 20, ..., 15, 17, 13],
#        [16, 13, 25, ...,  7, 13,  6],
#        [13, 22, 18, ..., 10,  9, 16]])
# Coordinates:
#   * chain    (chain) int64 0 1 2 3
#   * draw     (draw) int64 0 1 2 3 4 5 6 7 8 ... 992 993 994 995 996 997 998 999

# %%
az.plot_posterior(post_pred.posterior_predictive.obs, hdi_prob=0.8)
plt.show()

# %%
post = az.extract(idata)
post["theta"].size
# Out:
# 4000

# %%
y_rep = stats.binom.rvs(n=20, p=post["theta"])

# %%
az.plot_posterior(y_rep, hdi_prob=0.8, kind="kde", bw=0.5)
plt.show()

# %%
print(alpha_prior, beta_prior)
# Out:
# 4 6

# %%
with model:
    idata_prior_pred = pm.sample_prior_predictive()
# Out:
# Sampling: [obs, theta]

# %%
idata_prior_pred
# Out:
# Inference data with groups:
# 	> prior
# 	> prior_predictive
# 	> observed_data

# %%
az.plot_posterior(idata_prior_pred.prior_predictive.obs)
plt.show()

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Tue Feb 06 2024
#
# Python implementation: CPython
# Python version       : 3.11.7
# IPython version      : 8.19.0
#
# pymc      : 5.10.3
# arviz     : 0.17.0
# scipy     : 1.11.4
# numpy     : 1.26.2
# seaborn   : 0.13.0
# pandas    : 2.1.4
# matplotlib: 3.8.2
#
# Watermark: 2.4.3
