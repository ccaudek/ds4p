# %%
from scipy import stats
import pymc as pm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-darkgrid")
sns.set_theme(palette="colorblind")

# %%
good_chains = stats.beta.rvs(2, 5, size=(2, 2000))
bad_chains0 = np.random.normal(
    np.sort(good_chains, axis=None), 0.05, size=4000
).reshape(2, -1)

bad_chains1 = good_chains.copy()
for i in np.random.randint(1900, size=4):
    bad_chains1[i % 2 :, i : i + 100] = np.random.beta(i, 950, size=100)

chains = {
    "good_chains": good_chains,
    "bad_chains0": bad_chains0,
    "bad_chains1": bad_chains1,
}

# %%
_ = az.plot_trace(chains)
plt.tight_layout()

# %%
fig, ax = plt.subplots(3, 1)  
az.plot_autocorr(chains, combined=True, ax=ax)
plt.tight_layout()

# %%
_, axes = plt.subplots(2, 3, sharey=True, sharex=True)
az.plot_ess(chains, kind="local", ax=axes[0])
az.plot_ess(chains, kind="quantile", ax=axes[1])

for ax_ in axes[0]:
    ax_.set_xlabel("")
for ax_ in axes[1]:
    ax_.set_title("")

for ax_ in axes[:, 1:].ravel():
    ax_.set_ylabel("")
plt.ylim(-100, 5000);

# %%
az.rhat(chains)
# Out:
# <xarray.Dataset>
# Dimensions:      ()
# Data variables:
#     good_chains  float64 0.9998
#     bad_chains0  float64 2.389
#     bad_chains1  float64 1.003

# %%
az.mcse(chains)
# Out:
# <xarray.Dataset>
# Dimensions:      ()
# Data variables:
#     good_chains  float64 0.002645
#     bad_chains0  float64 0.1058
#     bad_chains1  float64 0.007312

# %%
fig, ax = plt.subplots(3, 1, figsize=(7, 9))  
az.plot_mcse(chains, ax=ax)
plt.tight_layout()

# %%
fig, ax = plt.subplots(3, 1, figsize=(7, 8))  
az.plot_rank(chains, kind="bars", ax=ax)
plt.tight_layout()

# %%
fig, ax = plt.subplots(3, 1, figsize=(7, 8))  
az.plot_rank(chains, kind="vlines", ax=ax)
plt.tight_layout()

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w -m
# Out:
# Last updated: Tue Feb 06 2024
#
# Python implementation: CPython
# Python version       : 3.11.7
# IPython version      : 8.19.0
#
# Compiler    : Clang 16.0.6
# OS          : Darwin
# Release     : 23.3.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 8
# Architecture: 64bit
#
# seaborn   : 0.13.0
# pymc      : 5.10.3
# matplotlib: 3.8.2
# numpy     : 1.26.2
# arviz     : 0.17.0
# scipy     : 1.11.4
#
# Watermark: 2.4.3
